# %% [markdown]
# # ADVANCED STATISTICS IN DATA SCIENCE

# %% [markdown]
# # QUESTION: APPLY ADVANCED STATISTICAL TECHNIQUES TO A DATASET, PRESENTING FINDINGS AND INSIGHT

# %% [markdown]
# ## 1. Importing libraries

# %%
# importing libraries 
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import seaborn as sns

# %% [markdown]
# ## 2. Importing dataset from excel

# %%
# importing dataset from excel
df = pd.read_excel (r"C:\Users\USER\Documents\Data set 3mtt.xlsx")

# %% [markdown]
# ## 3. Displaying dataset

# %%
# Displaying dataset
df
# Out:
#          Fellow ID First_name   Surname    Phone_number Gender  Age  \
# 0   FE/23/34641235      Amina     Shehu    080-56473399      F   25
# 1   FE/23/14442555      Aisha    Bashir    07-059212377      F   23
# 2   FE/23/13452341     Khalid     Usman    091-38336577      M   28
# 3   FE/23/56523760       Umar      Sani    080-23059181      M   26
# 4   FE/23/14432556     Maryam  Mustapha    091-23473322      F   27
# 5   FE/23/86586533   Abubakar     Aminu    08-027471560      M   32
# 6   FE/23/23456123     Zainab   Mukhtar    070-45667787      F   25
# 7   FE/23/15663456     Mansur   Murtala    0704-4321111      M   29
# 8   FE/23/33452611     Mariya      Sani    09-144555526      F   28
# 9   FE/23/46335444     Halima      Imam    081-40469709      F   25
# 10  FE/23/54279987      Faith    Ogoche    080-33339876      F   23
# 11  FE/23/54244987      Rahma  Mustapha    080-55777733      F   28
# 12  FE/23/15554323      Aliyu  Alhassan    070338-72211      M   26
# ...

# %% [markdown]
# ## 4. Understanding the dataset

# %%
# dataset shape
df.shape
# Out:
# (23, 9)

# %%
# dataset types
df.dtypes
# Out:
# Fellow ID             object
# First_name            object
# Surname               object
# Phone_number          object
# Gender                object
# Age                    int64
# Education_level       object
# State_of_Residence    object
# Skill_level           object
# dtype: object

# %%
# describing the dataset
df.describe()
# Out:
#              Age
# count  23.000000
# mean   26.739130
# std     2.453521
# min    23.000000
# 25%    25.000000
# 50%    27.000000
# 75%    28.000000
# max    32.000000

# %% [markdown]
# ## Preparing dataset

# %%
# cleaning and standardizing phone numbers
df["Phone_number"] = df["Phone_number"].str.replace('-', '')
df
# Out:
#          Fellow ID First_name   Surname Phone_number Gender  Age  \
# 0   FE/23/34641235      Amina     Shehu  08056473399      F   25
# 1   FE/23/14442555      Aisha    Bashir  07059212377      F   23
# 2   FE/23/13452341     Khalid     Usman  09138336577      M   28
# 3   FE/23/56523760       Umar      Sani  08023059181      M   26
# 4   FE/23/14432556     Maryam  Mustapha  09123473322      F   27
# 5   FE/23/86586533   Abubakar     Aminu  08027471560      M   32
# 6   FE/23/23456123     Zainab   Mukhtar  07045667787      F   25
# 7   FE/23/15663456     Mansur   Murtala  07044321111      M   29
# 8   FE/23/33452611     Mariya      Sani  09144555526      F   28
# 9   FE/23/46335444     Halima      Imam  08140469709      F   25
# 10  FE/23/54279987      Faith    Ogoche  08033339876      F   23
# 11  FE/23/54244987      Rahma  Mustapha  08055777733      F   28
# 12  FE/23/15554323      Aliyu  Alhassan  07033872211      M   26
# ...

# %% [markdown]
# ## 5. Feature Understanding

# %%
# Bar chart
ax = df['Age'].value_counts().plot(kind = 'bar', title = 'AVERAGE AGE OF APPLICANTS')
ax.set_xlabel('Age of Applicants')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %%
# Density plot
ax = df['Age'].plot(kind = 'kde', title = 'AVERAGE AGE OF APPLICANTS')
ax.set_xlabel('Age of Applicants')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')
